# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2


from single_inlet_moving_boundary.cswe_harm import *
import matplotlib.pyplot as plt

# %%
computation = CSWEHarm()
# computation.r = 0.2
computation.small_number = 0
s0 = computation.solve_LO()
# Out:
#        message: The maximum number of mesh nodes is exceeded.
#        success: False
#         status: 1
#              x: [ 0.000e+00  9.510e-04 ...  9.999e-01  1.000e+00]
#            sol: <scipy.interpolate._interpolate.PPoly object at 0x0000017E4FCDA440>
#              p: None
#              y: [[ 1.000e+00  1.000e+00 ...  1.018e+00  1.018e+00]
#                  [ 0.000e+00  4.202e-06 ...  2.633e-02  2.641e-02]
#                  [ 4.362e-03  4.366e-03 ...  2.637e-02  2.641e-02]
#                  [-1.009e+00 -1.009e+00 ... -1.018e+00 -1.018e+00]]
#             yp: [[ 1.810e-02  1.810e-02 ... -2.630e-02 -2.726e-02]
#                  [ 4.417e-03  4.421e-03 ...  1.721e+00  1.755e+00]
#                  [ 4.362e-03  4.366e-03 ...  8.604e-01  8.776e-01]
#                  [-9.052e-03 -9.052e-03 ...  1.315e-02  1.363e-02]]
#  rms_residuals: [ 2.028e-13  2.934e-13 ...  1.981e-07  2.119e-07]
#          niter: 35
# ...

# %%
s1 = computation.solve_FO()
computation.plot_components()
# Out:
# [0.51327482 0.52396007 0.53511916 0.54678304]
# [-1.37162368 -1.39335818 -1.41589143 -1.43926889]
# [0.24828887 0.24704614 0.24575624 0.24441645]
# -----
# [0.51327482 0.52396007 0.53511916 0.54678304]
# [-1.37162368 -1.39335818 -1.41589143 -1.43926889]
# [0.24828887 0.24704614 0.24575624 0.24441645]
# -----
# [0.50812805 0.51858869 0.52950919 0.54049234]
# [-1.36119795 -1.38255829 -1.40469645 -1.42808181]
# [0.24888467 0.24766404 0.24639749 0.24505938]
# -----
# [0.51327482 0.52396007 0.53511916 0.54678304]
# [-1.37162368 -1.39335818 -1.41589143 -1.43926889]
# [0.24828887 0.24704614 0.24575624 0.24441645]
# -----
# [0.51327482 0.52396007 0.53511916 0.54678304]
# [-1.37162368 -1.39335818 -1.41589143 -1.43926889]
# [0.2482889  0.24704617 0.24575628 0.24441649]
# -----
# [0.51327482 0.52396007 0.53511916 0.54678304]
# [-1.37162372 -1.39335821 -1.41589146 -1.43926892]
# [0.24828887 0.24704614 0.24575624 0.24441645]
# -----
# [0.51327483 0.52396009 0.53511917 0.54678306]
# ...

# %%
computation.generate_meshes()
computation.heatmaps()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 computation.generate_meshes()
#       2 computation.heatmaps()
#
# File c:\Users\jolieken\OneDrive - UGent\Documents\Code\1D\single_inlet_moving_boundary\cswe_harm.py:396, in generate_meshes(self)
#     393 self.t = np.linspace(0, 2*pi, 1000)
#     394 self.x = np.linspace(0, 1, 1000)
# --> 396 dz0_c, dz0_s, u0_c, u0_s = self.pol0(self.x)
#     397 dz1_r, dz1_c, dz1_s, u1_r, u1_c, u1_s = self.pol1(self.x)
#     399 self.dz0_xt = 0 + \
#     400     dz0_c[:, np.newaxis] * cos(self.t[np.newaxis, :]) + \
#     401     dz0_s[:, np.newaxis] * sin(self.t[np.newaxis, :])
#
# AttributeError: 'CSWEHarm' object has no attribute 'pol1'
